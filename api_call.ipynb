# %% [markdown]
# ## Preliminaries

# %%
# Dependencies
import pickle
import json
from openai import OpenAI
import numpy as np
import os
import pandas as pd
import time
from pydantic import BaseModel, field_validator
import instructor

# %%
from typing import List

class entity(BaseModel):
    id: int
    name: str

class relation(BaseModel):
    source: int
    target: int
    label: str

class triplet(BaseModel):
    nodes: List[Node] = Field(..., default_factory=list)
    edges: List[Edge] = Field(..., default_factory=list)

# %%
client = instructor.patch(OpenAI())

model = client.chat.completions.create(
    model="gpt-3.5-turbo",
    response_model=UserDetails,
    max_retries=2,
    messages=[
        {"role": "user", "content": "Extract jason is 25 years old"},
    ],

# %%
# Assume you have a file named 'example.pkl' containing a pickled object
with open('../ssdh_all_raw_message', 'rb') as file:
    # Load the pickled object back into Python
    unpickled_object = pickle.load(file)

# The client for the API
client = OpenAI()

# %%
# Document slicing
documents = []
for i in range(0, int(len(unpickled_object)/2)):
    documents.append(unpickled_object[2*i])

# %% [markdown]
# ## Single prompt test for the API

# %%
# Original, non-modified prompt
prompt_file = open('prompts/original.txt','r').read()

# Assistant creation
assistant = client.beta.assistants.create(
    name="Chilean History Expert",
    instructions=prompt_file,
    model="gpt-4" # gpt-4 turbo is x2 times exprensive
)

# %%
# 'Conversation thread' creation
thread = client.beta.threads.create()

# Single message added
msg = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content=documents[19]
)

# Run the model
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
)

# %%
# Check if the run is completed
run = client.beta.threads.runs.retrieve(
  thread_id=thread.id,
  run_id=run.id
)
print(run.status)
# Out:
# completed

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)
messages.data[0].content[0].text.value
# Out:
# SyncCursorPage[ThreadMessage](data=[ThreadMessage(id='msg_2xs5MBcLdvOVrOdEoG4Wo5Pl', assistant_id='asst_OnVlScN4AOSqVpRvDSA0gLZ4', content=[MessageContentText(text=Text(annotations=[], value="{'Gregorio BRAVO Ponce de Leon': [('Position within prison', 'Member of the Well-being Committee responsible for improving detention conditions'), ('Location', 'Held in the prison characterized by overcrowding, insufficient hygienic conditions and insufficient medical attention, particularly in case of emergencies')],\n 'Carlos RIOS Fuentes': [('Position within prison', 'Member of the Well-being Committee responsible for improving detention conditions'), ('Location', 'Held in the prison characterized by overcrowding, insufficient hygienic conditions and insufficient medical attention, particularly in case of emergencies')],\n 'German CALLEJAS Guerrero': [('Position within prison', 'Member of the Well-being Committee responsible for improving detention conditions'), ('Location', 'Held in the prison characterized by overcrowding, insufficient hygienic conditions and insufficient medical attention, particularly in case of emergencies')]}"), type='text')], created_at=1706205379, file_ids=[], metadata={}, object='thread.message', role='assistant', run_id='run_IurI7y67lgk8u5OBWmgmZqg4', thread_id='thread_SebfrvAqGX0An3WyrCmbUR6F'), ThreadMessage(id='msg_vqtUS6TJasz7HzfYOV0KzvGh', assistant_id=None, content=[MessageContentText(text=Text(annotations=[], value='Trato y disciplina: Los detenidos de las galerías 5 y 6 se han organizado, eligiendo\na un Comite de Bienestar, integrado por los señores Gregorio BRAVO Ponce de\nLeon, Carlos RIOS Fuentes y German CALLEJAS Guerrero. El trabajo del mismo\nComité consiste en mejorar, en colaboración con las Autoridades de la Car-\ncel, las condiciones de detención, o sea coordinar las distintas obras de\nmejoras, velar por las condiciones higiénicas y administrar un pequeflo fondo\ndestinado a sufragar las mejoras mas urgentes, Con ocasión de su visita, los\ndelegados del CICR entregaron 2 20.000 para dicho fondo, mantenido por los\nde tenidos mismos bajo las supervisiones del señor Alcaide.\nEl referido Comité dispone de un llamado "Libro de Control de Cargas Fisca-\nles", que sirve para controlar todos los aportes de la Cruz Roja.\n1 trato sigue siendo normal dentro del recinto carcelario.\nEn cuanto a los incomunicados, los delegados no pueden afirmarlo, porque\nlas costumbres del CICH.\nlas Autoridades rehusaron la entrevista a solas con ellos, contrariamente a\nEs de señalarse que entre los detenidos a disposicion de las Autoridades\nMilitares hay delincuentes comunes reincidentes. Tal hecho es contrario a\nlas costumbres penitenciarias y no deja de provocar problemas de disciplina.\nVarios detenidos recien llegados del Campo de Tejas Verdes se quejaron de\nmalos tratos sufridos en dicho lugar, durante interrogatorios. \nLos \ndelegados\npudieron comprobar contusiones abdominales y toracicas, \nuñas arrancadas,\ndientes quebrados, desprendimiento de la retina\n.\nConclusiones: Las condiciones de hacinamiento siguen siendo inaceptables.\nLas condiciones higiénicas son insuficientes, así como la atención médica,\nsobre todo en caso de emergencia.\nAsistencia del CICR : En marzo de 1974, los mismos delegados entregaron :\n30 baldes plásticos sin tapa\n15 escobillones\n2 galones de pintura blanca al óleo\n1 brocha gorda\nherramientas\nL\nmaquina y tijeras para cortar el pelo\n1 cortina de plástico\n2 pelotas: 1 de baby-futbol y 1 de basquetbol\n3 paletas y 12 pelotas de ping pong\n- 5 ajedrez\nA\n2458-24 MA 1974\n'), type='text')], created_at=1706205377, file_ids=[], metadata={}, object='thread.message', role='user', run_id=None, thread_id='thread_SebfrvAqGX0An3WyrCmbUR6F')], object='list', first_id='msg_2xs5MBcLdvOVrOdEoG4Wo5Pl', last_id='msg_vqtUS6TJasz7HzfYOV0KzvGh', has_more=False)

# %% [markdown]
# ## Prompt Testing Framework

# %% [markdown]
# ## Prompt engineering tactics
# The idea is to follow some of the [strategies given by OpenAI](https://platform.openai.com/docs/guides/prompt-engineering) for getting better results using prompt engineering.
# The original prompt will be used as a base.

# %% [markdown]
# ### Write clear instructions
# 1. Let the model guess as little as possible.
# 2. Step-by-step instructions (also trying the 'magical' sentence [Take a deep breath and work on this problem step-by-step](https://arxiv.org/pdf/2309.03409.pdf)).
# ### Split complex tasks into simpler subtasks
# 3. Recursively summarize and clean text.
# ### Give the model time to "think"
# 4. Ask if there are any relevant info that was left behind. Tell them to not repeat info.
# (ex. Are there more relevant excerpts? Take care not to repeat excerpts. Also ensure that excerpts contain all relevant context needed to interpret them - in other words don't extract small snippets that are missing important context.)

# %% [markdown]
# ### TBA
# #### Use external tools
# - APIs.
# - Functions.
# #### Test changes systematically
# - [https://github.com/openai/evals/tree/main]
# - [https://www.deeplearning.ai/short-courses/automated-testing-llmops/]

# %% [markdown]
# ### Leap of faith
# If it's important to reduce the API calls, we can make the assumption that the tactics presented above act like monotone increasing functions. Thus, we can prune some prompt variations.
#
# i.e, given two 'different enough' prompts A and B,
# if A gets better results than B, then none of the above tactics combinations applied to B, will get
# better results than A with the same tactics applied.

# %% [markdown]
# ## Prompts description
# Row 0 correspond to the different prompts written in the './prompts' directory.
#
# Column 0 corresond to the strategies presented above, each represented with their respective number.
# |    | var1 | var2 | var3 | var4 | var5 | var6 | var7 | var8 |
# |----|------|------|------|------|------|------|------|------|
# | (1)|  ✅  |  ✅   | ✅   | ✅   | ✅   | ✅   | ✅   | ✅  |
# | (2)|  -   |  ✅  |  -   |  ✅   | -   | - | ✅   | ✅ |
# | (3)| -   | -   | ✅   |  ✅  | - | ✅   | -   | ✅   |
# | (4)| -   | -   | -   |  -  | ✅   | ✅   | ✅   | ✅   |

# %%
# 3, 5, 11, 17, 19 will be used as sample for manual evaluation
# document 17 gets no result from the original prompt (added on purpose)
documents_sample = []
for i in [3, 5, 11, 17, 19]:
    documents_sample.append(documents[i])

directory = "./prompts/"
prompts = []
for prompt in os.listdir(directory):
    with open(os.path.join(directory, prompt), 'r', encoding='utf-8') as file:
        prompts.append(file.read())

# %%
def results_to_df(prompts_batch, data_samples, openai_client):

    df = pd.DataFrame(columns=['prompt', 'document', 'result']) # df to return

    for prompt_idx, prompt in enumerate(prompts_batch):

        assistant = openai_client.beta.assistants.create(
            name="Chilean History Expert",
            instructions=prompt,
            model="gpt-4"
        )

        for doc_idx, doc in enumerate(data_samples):
            thread = openai_client.beta.threads.create()
            print(f"new thread created with id: {thread.id}.")

            m = openai_client.beta.threads.messages.create(
                thread_id=thread.id,
                role="user",
                content=doc
            )
            print(f"new message created with id: {m.id}.")

            run = openai_client.beta.threads.runs.create(
                thread_id=thread.id,
                assistant_id=assistant.id,
            )

            print(f"run instance created with id: {run.id}.")

            # wait while the assistant completes the answer
            run_status = ''
            while run_status != 'completed':
                print(f"run status: {run_status}.")
                run_status = openai_client.beta.threads.runs.retrieve(
                    thread_id=thread.id,
                    run_id=run.id
                ).status
                time.sleep(3)
            print(f"run status: {run_status}.")

            # assistant answer
            msg = openai_client.beta.threads.messages.list(
                thread_id=thread.id
            ).data[0].content[0].text.value

            # append row to df
            row = {'prompt' : prompt_idx, 'document' : doc_idx, 'result' : msg}
            df = pd.concat([df, pd.DataFrame.from_records([row])])
            print(f"Document {doc_idx} done.")

        print(f"Prompt {prompt_idx} done.")

    return df

# %%
df_results = results_to_df(prompts, documents_sample, client)
df_results
# Out:
# new thread created with id: thread_pjK5XxNc8kLTFCOfH34zVn9Y.
# new message created with id: msg_uR3wpmvnfAX7wjDe05jZIxk9.
# run instance created with id: run_wrgKYus3mCW57qBvzAJJmNCn.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 0 done.
# new thread created with id: thread_bWnvjQ9KBFDDF5Kq5yklUOXR.
# new message created with id: msg_n1nMuBHcg5Zfg4hzpedPsHUQ.
# run instance created with id: run_OnhfwQVjUvmTtidzLHFo3vI3.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 1 done.
# new thread created with id: thread_SIL1yGzO33SmosdGNtiomcfS.
# new message created with id: msg_JAXKzYRIgR2HqBgwmGs0fTaK.
# run instance created with id: run_6eju6Ps8QlFzbDsZ5KoEgpxK.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 2 done.
# new thread created with id: thread_ZjbUpHRcmAJtiNtXWO8BumvF.
# new message created with id: msg_bMzhN2FtBrX1KC7AtB7uDNO6.
# run instance created with id: run_QbxALe84UMZHeztkecRccJVx.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 3 done.
# new thread created with id: thread_FJtbVQTZKYSJhLB5e6t6CypM.
# new message created with id: msg_G9sfMesdYnEEZTxlglvONq5m.
# run instance created with id: run_AIUo7GxouZDBzbqtbR0wm7LX.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 4 done.
# Prompt 0 done.
# new thread created with id: thread_O4Nz6k0YK1vvhyMZpdnsfvxl.
# new message created with id: msg_ZfMacH49DDlVHj9B25SZwz5E.
# run instance created with id: run_VJCKjrTnEa7Ee4aAVWNNUPus.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 0 done.
# new thread created with id: thread_9S1LYKlcNjadivPVGYXCrUsY.
# new message created with id: msg_bDnnYN7nEUgJ9QVQX0I9C3Fr.
# run instance created with id: run_V3m5D9nAqxdiEmiDbq1ffaen.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 1 done.
# new thread created with id: thread_KQWSBtdTNVEqzx8VXLZ1fE6u.
# new message created with id: msg_HZ6RpR2sn27E3zK0HBqxAmch.
# run instance created with id: run_cjIHGpFPFrX6Rw7PPE4OEWbd.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 2 done.
# new thread created with id: thread_CueGJzv0ypWDYJ6OrjRxoOMf.
# new message created with id: msg_7BIfPpCaSIiR03EfvMBnMAVo.
# run instance created with id: run_d7PWKorDWeZvqKYYIcalBiSx.
# run status: .
# run status: in_progress.
# run status: completed.
# Document 3 done.
# new thread created with id: thread_2nVE14OvtZ6Z04BdwNA6UQIT.
# new message created with id: msg_IL8ckHNwAKlCitVDkq80SD4z.
# run instance created with id: run_2bdVmfm65g7bsnAvICkpi7Xb.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 4 done.
# Prompt 1 done.
# new thread created with id: thread_ram5G8F1zNWGQkkEoDtWICrU.
# new message created with id: msg_e8FwNXATs4hYhUQM3JbbRSxb.
# run instance created with id: run_GG0hWN2FCktU7Ucqm8CUF44Y.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 0 done.
# new thread created with id: thread_K4dOjbt7PcsO3QZjAuVo2SLV.
# new message created with id: msg_HvpBTr0M8gua4rcHA4eFSosi.
# run instance created with id: run_KZDn7WUK3ppQmU26DqzdwJlE.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 1 done.
# new thread created with id: thread_8UqRQXOrYmAxbJMJkzwcQ43k.
# new message created with id: msg_xorGWe20Z1Ka3AKWWEZow80x.
# run instance created with id: run_PUTnRtudJGkWXkv34bItRbx4.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 2 done.
# new thread created with id: thread_4Vt1qJuCnXwYk8oe57SvgngO.
# new message created with id: msg_A4Rnh5C8KCCYKhXsj29IdUUb.
# run instance created with id: run_lnmF8x1KdBny0r2L58Ko38zp.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 3 done.
# new thread created with id: thread_ETTAeGewiPGgrOkAlVeMsdNU.
# new message created with id: msg_mOEoyiPIEBI06sfnSMj35QxO.
# run instance created with id: run_Ey9M0QbygRHe6qHcFwftp4BD.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 4 done.
# Prompt 2 done.
# new thread created with id: thread_rGtxRnVBLEFU6RBsGeClpnua.
# new message created with id: msg_T9IvPm0nDWPMtpzTZtqFwTki.
# run instance created with id: run_UwCcEcIOkumIZHhEu40EIHsI.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 0 done.
# new thread created with id: thread_5IzmO1qnEuyYEvtEpYfUA72o.
# new message created with id: msg_RBTveyX7mLrcXDnp4vvGLxFg.
# run instance created with id: run_qeGzeLhswL28NkRhJdMWyarA.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 1 done.
# new thread created with id: thread_4L6baRhT0klPjL8lPQXyoO2x.
# new message created with id: msg_yZN8uyJIjLKlS0R0uKm1JAFS.
# run instance created with id: run_nKSrmSNRNvW5R7FChkgUkuXw.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 2 done.
# new thread created with id: thread_7QO4MxSvpqzMHy4J1yr3FtSl.
# new message created with id: msg_DZQJFl4e5yj9zqCYLJU90Oa1.
# run instance created with id: run_SFRl0Y5odjE1GKz9K9IxGidH.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 3 done.
# new thread created with id: thread_HXrYeciv00frF2AsfrdTChwg.
# new message created with id: msg_MhVu5IC2Xl8DH9caunD7dadu.
# run instance created with id: run_eLnTeezrGo170rAUIocnhOMa.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 4 done.
# Prompt 3 done.
# new thread created with id: thread_E75QO3SEHCcCB2SWddFBU55l.
# new message created with id: msg_tdHdktvJrNgksm44n0EcZEHY.
# run instance created with id: run_tcnwKVhOI2vZpjhvmmY92gVt.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 0 done.
# new thread created with id: thread_GK32XeWIfVjNP8kX5CQIlLfK.
# new message created with id: msg_IKTGoOosJG0ti6qe5hfYNXFA.
# run instance created with id: run_UYkLlyDmIj3I4diBqN1BCcrt.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 1 done.
# new thread created with id: thread_N1ndbWHvuUu1hfDAy2vRnTl9.
# new message created with id: msg_TPOpIuY7gEZVOIxmYh8QmXBv.
# run instance created with id: run_CzrzR03DLt8cfkAc528fJurH.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 2 done.
# new thread created with id: thread_wui6kzySuCEjaxw9WQF4W0uh.
# new message created with id: msg_QOuMN5w4o0VQBsFpYaiAV8qN.
# run instance created with id: run_WwJN1XCnsTk5ljQyCHqm6OB5.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 3 done.
# new thread created with id: thread_PW0RF2icSLc1NAmze6EUmNrQ.
# new message created with id: msg_ut5o06Geza0zed2o0pmEqLQF.
# run instance created with id: run_5v8IhL3tIbv3XuAHIFDufLPV.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 4 done.
# Prompt 4 done.
# new thread created with id: thread_iZwwqDnXK1HoMOi3BYI3nxx3.
# new message created with id: msg_YrbRR3vAsevZNTWfYUaOEQUl.
# run instance created with id: run_WI3dHIE4lVwC3JfCW7HYQhmp.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 0 done.
# new thread created with id: thread_zKDxsLIcpmnPbyFlbO9VX7XA.
# new message created with id: msg_KeIdlNoPUDvwDzQ65xSAO7Sf.
# run instance created with id: run_jxwtansjdEtzl7m06DnL1S5F.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 1 done.
# new thread created with id: thread_jN7MZo9AoEWZXJvATZKB1Omo.
# new message created with id: msg_yLwOLUzZVznrXCGW3SS0T6bo.
# run instance created with id: run_0B7ItRWuR7D1wRQS3XLp5cmm.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 2 done.
# new thread created with id: thread_ikdYapuqDPUbbQHlQASa87kF.
# new message created with id: msg_4f55dxx2CRZgUJlhx81frnhm.
# run instance created with id: run_oMYvgiP9nJVYex0vh62KYuRX.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 3 done.
# new thread created with id: thread_BdouYNrvHUk5hpkxbQxbSUYt.
# new message created with id: msg_lvWFt1wAxgnGarnUSWm7Ur8u.
# run instance created with id: run_R04dX6FD1m2mTa1Mna2TWGkU.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 4 done.
# Prompt 5 done.
# new thread created with id: thread_UjiUdt79DZ1KcnsVe6qqZmfa.
# new message created with id: msg_wiQYEzmiXmjw7jgq6btheIhK.
# run instance created with id: run_TpsSQQVf2xQfJBC5AmnTPrxC.
# run status: .
# run status: queued.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 0 done.
# new thread created with id: thread_at94qVoD9Gx96ZclazViJfVd.
# new message created with id: msg_airggi9U6ZttkfunoLgDg20z.
# run instance created with id: run_29g2hZntLC4dOWTUNfILVDDZ.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 1 done.
# new thread created with id: thread_yVHJ5L8oU399HlG0XGfVsrWK.
# new message created with id: msg_uNkMhDeSO0dDLydAtjCEXu7R.
# run instance created with id: run_wssilBNpG88RDKLvANkDAjvY.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 2 done.
# new thread created with id: thread_VcVPzZUBKFUETwFa9JQLl2V7.
# new message created with id: msg_UmpRYEz9zj87vPkrKsehkaVl.
# run instance created with id: run_zlohVREZJaM8xTsLGsddPNvf.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 3 done.
# new thread created with id: thread_FAh4TuZWllkSYFhgDi5KwHX5.
# new message created with id: msg_6sOi3CjEHlrfeCpwjh83wZa8.
# run instance created with id: run_bPHnrLpbo0NXGoGwwrlvQCxS.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 4 done.
# Prompt 6 done.
# new thread created with id: thread_Z1k6fYz9RkNKmMmHlqKWQXCe.
# new message created with id: msg_7TdfE0ki3NUXA4yFkScG547t.
# run instance created with id: run_WSP64zSbvOWKD1rBoREawYAB.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 0 done.
# new thread created with id: thread_0DzjdhrfL0ts0cYYSX2xpsxy.
# new message created with id: msg_xaf4vOWwEWulvsutt1a0lTqK.
# run instance created with id: run_mfbn0QGfYnjsoolULdd5zaJ7.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 1 done.
# new thread created with id: thread_4nRxIlTLvmphhr6bxvWYdSK7.
# new message created with id: msg_LM9715Ska6i4vsFh6869YROQ.
# run instance created with id: run_75wytH2EJrRYHWhvLdi0nrZD.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 2 done.
# new thread created with id: thread_gL0JQSDT3BEBXipgmW32MHne.
# new message created with id: msg_44SE04yJMdEJYgzAGlkOox2k.
# run instance created with id: run_hEG74NcfDhYowmbagl1VDCZK.
# run status: .
# run status: in_progress.
# run status: completed.
# Document 3 done.
# new thread created with id: thread_05l30L7k4Q5isGyYg6zkEcXd.
# new message created with id: msg_WcsDLAVc80w6RsKBl5gBaVia.
# run instance created with id: run_2AyTMHCrYoiWKFh4Tj5rOZrn.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 4 done.
# Prompt 7 done.
# new thread created with id: thread_p24I8jwAwqm35dc9HwnzPsNa.
# new message created with id: msg_M0HVyNqPeYKIYb7lyenTFgqi.
# run instance created with id: run_0EiI0Ue21wjjKMNizO36m1hF.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 0 done.
# new thread created with id: thread_VPoNajhjf6N0H6NwhoUjJY6u.
# new message created with id: msg_Q3m9H8NZ2tZDTy6JOJHpFvJp.
# run instance created with id: run_qESIR9ulURCBaGsto7KAru7W.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 1 done.
# new thread created with id: thread_k5GIjaeTqiYnFNior83Pi1uw.
# new message created with id: msg_FnpLS6LUc7d21bZLiEyRp08R.
# run instance created with id: run_3Q1DX5X4lIHlslLOtD9LEv74.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 2 done.
# new thread created with id: thread_tQ0aYKdwCnpKBPr8BKLYgkBV.
# new message created with id: msg_IUxlqW8LWf8A6jcvT0InowOf.
# run instance created with id: run_hIaXMVWl7EDOUxaSNAUWEvWA.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 3 done.
# new thread created with id: thread_jT0HoOHJHBGMZIfF1WQBDLxP.
# new message created with id: msg_Y12NeT9wKj5SbacIYmCkVuzL.
# run instance created with id: run_MzZzpOzQl7W4OLEmdi62et1w.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: completed.
# Document 4 done.
# Prompt 8 done.
#   prompt document                                             result
# 0      0        0  This is a translated summary of the provided d...
# 0      0        1  {'Julio Arturo Acosta Georges': [('Personal in...
# 0      0        2  Step 1:\nThe document describes the living con...
# 0      0        3  As the given document seems to be a part of an...
# 0      0        4  Step 1 - The document is a report related to t...
# 0      1        0  {'Teniente Gonzalo Durán Paredes': [('Responsi...
# 0      1        1  {'Manuel Contreras Sepulveda': [('Coronel', 'D...
# 0      1        2  {'Jorge GONZALEZ Morales': [('Detention and He...
# 0      1        3  The provided document does not provide informa...
# 0      1        4  {'Gregorio BRAVO Ponce de Leon': [('Position',...
# 0      2        0  {'Eddi Leemann': [('Role', 'Delegate of the IC...
# 0      2        1  {'Julio Arturo Acosta Georges': [('Arrest Date...
# 0      2        2  {'Jorge GONZALEZ Morales': [('Medical conditio...
# 0      2        3  The provided document doesn't provide any spec...
# 0      2        4  {'Gregorio BRAVO Ponce de Leon': [('Position',...
# 0      3        0  DOCUMENT SUMMARY:\n\nThe document titled "Info...
# 0      3        1  DOCUMENT SUMMARY AND CLEANING:\nThe document c...
# 0      3        2  DOCUMENT SUMMARY:\nThe document suggests poor ...
# 0      3        3  DOCUMENT SUMMARY:\nThis document is a communic...
# 0      3        4  DOCUMENT SUMMARY:\nThe document is about certa...
# 0      4        0  {'Gonzalo Durán Paredes': [('position', 'Respo...
# 0      4        1  {'Manuel Contreras Sepulveda': [('Position', '...
# 0      4        2  {'Jorge GONZALEZ Morales': [('Medical Informat...
# 0      4        3  The given document doesn't seem to contain inf...
# 0      4        4  {'Gregorio BRAVO Ponce de Leon': [('Role', 'Pa...
# 0      5        0  DOCUMENT SUMMARY:\nThe document is a report on...
# 0      5        1  Due to the length of the document and the char...
# 0      5        2  Cleaning and summarizing:\nThe document inspec...
# 0      5        3  Without the detailed contents of the main body...
# 0      5        4  DOCUMENT SUMMARY:\nThe document appears to be ...
# 0      6        0  {'Teniente Gonzalo Durán Paredes': [("Position...
# 0      6        1  {'ACOSTA GEORGES JULIO ARTURO': [('Arrested', ...
# 0      6        2  {'Jorge GONZALEZ Morales': [('Health condition...
# 0      6        3  The document provided does not contain specifi...
# 0      6        4  {'Gregorio Bravo Ponce de Leon': [('Role', 'Me...
# 0      7        0  {"Teniente Gonzalo Durán Paredes":[("Role","Re...
# 0      7        1  {'Manuel Contreras Sepulveda': [('Role', 'Dire...
# 0      7        2  {'Jorge GONZALEZ Morales': [('Health condition...
# 0      7        3  The document does not provide sufficient infor...
# 0      7        4  {'Gregorio BRAVO Ponce de Leon': [('Role in De...
# 0      8        0  DOCUMENT SUMMARY:\nThe document is a report on...
# 0      8        1  {'Manuel Contreras Sepulveda': [('Position', '...
# 0      8        2  Step 1 - Clean and summarize\nThe document per...
# 0      8        3  The information provided in this document is v...
# 0      8        4  Step 1 - Clean the DOCUMENT and summarize it:\...

# %%
df_results.to_csv('results.csv')

# %%
df_results['result'].array[1]
# Out:
# "{'Julio Arturo Acosta Georges': [('Personal information', 'Chilean, born on January 8, 1946. Single. Lived at Arturo Prat # 1897 El Perevic, Renca. He was a journalist.'), ('Political alignment', 'Had leftist sympathies.'), ('Arrests and releases', 'Detained by police on September 25, 1973 and released on February 13, 1974.'), ('Travel information', 'Documented in passenger list of CATA destined for Mendoza.'), ('Other', 'Worked as a press secretary for Hortencia Bussi de Allende. He recounted presidential information and foreign news, particularly about Mexico and Cuba.')], \n'Augusto Rene Alvarado Cardenas': [('Personal information', 'Chilean, civil number 5.809.709 from Santiago. Born on April 27, 1948 in Puerto Natales.'), ('Political alignment', 'Member of the former socialist party.'), ('Arrests', 'Detained for political activities as a leader of the Socialist Party. Documented to be detained in the city of Rancagua.')], \n'Rene Vicente Alvarez Gaete':[('Personal information', 'Chilean, civil number 5.392.505 from Santiago. Born on June 4, 1950. Was a student at the University of Antofagasta, lived at Gral.Darnell #1648, Ñuñoa.'), ('Political alignment', 'Member of the former socialist party.'), ('Arrests and sentences', 'Detained on October 26, 1973 for violation of law 17.798 and Internal State Security Law. Was sentenced to 13 years imprisonment.')], \n'Rene Albino Alvarez Martinez':[('Personal information', 'No specific personal details provided.'), ('Arrests', 'Detained on May 10, 1975 for violation of Band No. 211 of November 4, 1974. Was subjected to the Military Prosecutor of Victoria due to crossing yet-to-be-open cordilleran paths.')],\n'Rene Santiago Alvarez Bustos':[('Personal Information', 'Chilean, civil number 123.348 from Puerto Montt, married. Born on June 22, 1953. Was an student at INACAP and lived at Vicuña Rosa # 5290, Quinta Normal.'), ('Arrests and releases','Detained on September 12, 1973 for violating the curfew. Released on September 23, 1973.')] }"

# %%
file_name = f"prompt_0_results.txt"
f = open(f"results/{file_name}", 'a')

for i in range(5*8):
    prompt_num = int(i/5)
    if (prompt_num != int((i-1)/5)):
        f.close()
        file_name = f"prompt_{prompt_num}_results.txt"
        f = open(f"results/{file_name}", 'a')
    print(f"\nDOCUMENT {(i%5)}:\n", file=f)
    print(df_results['result'].array[i], file=f)
